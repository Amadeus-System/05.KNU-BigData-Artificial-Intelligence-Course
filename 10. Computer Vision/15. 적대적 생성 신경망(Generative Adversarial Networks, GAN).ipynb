# %% [markdown]
# - 내용 및 코드 참조
#
#   - 케라스 창시자로부터 배우는 딥러닝
#
#   - 미술관에 GAN 딥러닝 실전 프로젝트

# %% [markdown]
# # 적대적 생성 신경망(Generative Adversarial Networks, GAN)
#
# - 2014년, Ian Goodfellow 소개
#
# - VAE와는 다른 방법으로 이미지 잠재 공간을 학습
#
# - 직관적으로 이해하는 방법
#
#   - 가짜 피카소 그림을 그리는 위조범과 이를 판별하는 판매상의 관계
#
#   - 위조품과 진짜 그림을 섞어서 판매상에게 보여주며
#     그림이 진짜인지 가짜인지 판매상은 판별하고 이를 위조범에게 피드백
#
#   - 처음에는 형편없는 그림을 그리다가 점점 피카소의 스타일을 모방하게 되고
#     판매상은 위조품을 구분하는데 점점 더 전문가가 되어감
#
# - GAN의 네트워크
#
#   - 생성자 네트워크(generator network)
#
#     - 랜덤 벡터(잠재 공간의 무작위한 포인트)를 입력으로 받아 이를 합성된 이미지로 디코딩
#
#   - 판별자 네트워크(discriminator netowrk)
#
#     - 이미지(실제 또는 가짜 이미지)를 입력으로 받아 훈련 세트에서 온 이미지인지 생성자가 만든 이미지인지 판별
#
# - GAN은 최적화의 최솟값이 고정되어 있지 않음
#
#   - 보통의 경사하강법은 **고정된 손실공간**에서 언덕을 내려오는 훈련 방법이지만
#     GAN은 매 단계가 조금씩 전체 공간을 바꾸기 때문에 최적화 과정이 최솟값을 찾는 것이 어려움
#
#   - 두 힘간의 평형점을 찾는 시스템
#
#   - 따라서, 학습과정이 매우 어려움
#     즉, 적절한 파라미터를 찾고 조정해야함
#
#   <img src="https://paperswithcode.com/media/methods/gan.jpeg">
#
#   <sub>[이미지 출처] https://paperswithcode.com/method/gan</sub>

# %% [markdown]
# ## GAN의 구현 (DCGAN)
#
# - CIFAR10 데이터셋 사용
#
# - generator 네트워크는 (latent_dim,) 크기의 벡터를 (32, 32, 3) 크기의 이미지로 매핑
#
# - discriminator 네트워크는 (32, 32, 3) 크기의 이미지가 진짜일 확률을 추정하여 이진값으로 매핑
#
# - 생성자와 판별자를 연결하는 gan 네트워크를 만듬
#
#   - gan(x) = discriminator(generator(x))
#
# - 진짜/가짜 레이블과 함께 진짜 이미지와 가짜 이미지 샘플을 사용하여 판별자를 훈련 (일반적인 이미지 분류 모델 훈련과 동일)
#
# - 생성자를 훈련하려면 gan 모델의 손실에 대한 생성자 가중치의 그래디언트를 사용
#
#   - 매 단계마다 생성자에 의해 디코딩된 이미지를 판별자가 "진짜"로 분류하도록 만다는 방향으로 생성자의 가중치를 이동
#
#   - 판별자를 속이도록 생성자를 훈련한다는 말

# %% [markdown]
# ## 학습 방법
#
# - 마지막 활성화 함수로 sigmoid 대신 tanh함수 사용
#
# - 균등분포가 아니고 정규 분포(가우시안 분포)를 사용하여 잠재 공간에서 포인트를 샘플링
#
# - 무작위성을 주입
#
#   - 판별자에 드롭아웃을 사용
#
#   - 판별자를 위해 레이블에 랜덤 노이즈를 추가
#
# - 희소한 그래디언트는 GAN 훈련에 방해가 될 수 있음
#
#   - 최대 풀링 대신 스트라이드 합성곱을 사용하여 다운샘플링
#
#   - ReLU 대신 LeakyReLU 사용
#
# - 생성자에서 픽셀 공간을 균일하게 다루지 못하여 생성된 이미지에서 체스판 모양이 종종 나타남.
#   이를 위해 생성자와 판별자에서 스트라이드 Conv2DTranpose나 Conv2D를 사용할 때 스트라이드 크기로 나누어 질 수 있는 커널 크기 사용
#
#   - 커널 크기가 스트라이드의 배수가 아니면 픽셀이 공평하게 합성곱 되지 않음
#     커널 크기를 스트라이드로 나누었을 때 나머지 크기에 해당하는 픽셀이 더 많이 업샘플링에 참여하게 됨

# %% [markdown]
# ### GAN 생성자 네트워크

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, LeakyReLU, Reshape, Conv2D, Conv2DTranspose, Flatten, Dropout
from tensorflow.keras.models import Model
import numpy as np

# %%
latent_dim = 32
height = 32
width = 32
channels = 3

# %%
generator_input = Input(shape = (latent_dim, ))

# %%
x = Dense(128 * 16 * 16)(generator_input)
x = LeakyReLU()(x)
x = Reshape((16, 16, 128))(x)

x = Conv2D(256, 5, padding = 'same')(x)
x = LeakyReLU()(x)

x = Conv2DTranspose(256, 4, strides = 2, padding = 'same')(x)
x = LeakyReLU()(x)

x = Conv2D(256, 5, padding = 'same')(x)
x = LeakyReLU()(x)
x = Conv2D(256, 5, padding = 'same')(x)
x = LeakyReLU()(x)

x = Conv2D(channels, 7, activation = 'tanh', padding = 'same')(x)

# %%
generator = Model(generator_input, x)
generator.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32)]              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32768)             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### GAN 판별자 네트워크

# %%
discriminator_input = Input(shape = (height, width, channels))

# %%
x = Conv2D(128, 3)(discriminator_input)
x = LeakyReLU()(x)
x = Conv2D(128, 4, strides = 2)(x)
x = LeakyReLU()(x)
x = Conv2D(128, 4, strides = 2)(x)
x = LeakyReLU()(x)
x = Conv2D(128, 4, strides = 2)(x)
x = LeakyReLU()(x)
x = Flatten()(x)
x = Dropout(0.4)(x)
x = Dense(1, activation = 'sigmoid')(x)

# %%
discriminator = Model(discriminator_input, x)
discriminator.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop # root mean square propagation

# %%
discriminator_optimizer = RMSprop(lr = 0.0008, clipvalue = 1.0, decay = 1e-8)
discriminator.compile(optimizer = discriminator_optimizer, 
                      loss = 'binary_crossentropy')

# %% [markdown]
# ### 적대적 네트워크
# - 생성자와 판별자를 연결
#
# - 훈련할 때 생성자가 판별자를 속이는 능력이 커지도록 학습
#
# - 잠재 공간의 포인트를 진짜 또는 가짜의 분류 결정으로 변환
#
# - 훈련에 사용되는 target label은 항상 "진짜 이미지"
#
# - 훈련하는 동안 판별자를 동결(학습되지 않도록)하는 것이 매우 중요!
#
#   - 판별자의 가중치가 훈련하는 동안 업데이트되면 판별자는 항상 진짜를 예측하도록 훈련됨

# %%
discriminator.trainable = False

gan_input = Input(shape = (latent_dim, ))
gan_output = discriminator(generator(gan_input))
gan = Model(gan_input, gan_output)

gan_optimizer = RMSprop(lr = 0.0004, clipvalue = 1.0, decay = 1e-8)
gan.compile(optimizer = gan_optimizer, loss = 'binary_crossentropy')

# %% [markdown]
# ### GAN 훈련 구현
#
# - DCGAN 구현
#
# - 매 반복마다 아래의 과정 수행
#
#   1. 잠재 공간에서 무작위로 포인트를 뽑음(랜덤 노이즈)
#
#   2. 랜덤 노이즈를 사용하여 generator에서 이미지를 생성
#
#   3. 생성된 이미지와 진짜 이미지를 섞음
#
#   4. 진짜와 가짜가 섞인 이미지와 이에 대응하는 타깃을 사용하여 discriminator를 훈련
#     타킷은 진짜 또는 가짜
#
#   5. 잠재 공간에서 무작위로 새로운 포인트를 뽑음
#
#   6. 랜덤 벡터를 사용하여 gan을 훈련.
#     모든 타깃은 진짜로 설정.
#     - 판별자가 생성된 이미지를 모두 "진짜 이미지"라고 예측하도록 생성자의 가중치를 업데이트.
#       (판별자는 동결되기 때문에 생성자만 업데이트)

# %%
import os
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing import image

# %% [markdown]
# #### CIFAR10 데이터 로드

# %%
(x_train, y_train), (_, _) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %% [markdown]
# #### 개구리 이미지를 선택

# %%
x_train = x_train[y_train.flatten() == 6] # 개구리 데이터만 선택

# %% [markdown]
# #### 데이터 정규화

# %%
x_train = x_train.reshape((x_train.shape[0], ) + (height, width, channels)).astype('float32') / 255.

# %%
# gan은 학습이 잘 안됨
iterations = 10000
batch_size = 20

save_dir = '/content/gan_images'
if not os.path.exists(save_dir): # 디렉토리 존재 안하면
    os.mkdir(save_dir) # 디렉토리 만듬

# %% [markdown]
# #### 학습

# %%
start = 0
for step in range(iterations):

    random_latent_vectors = np.random.normal(size = (batch_size, latent_dim))
    generated_images = generator.predict(random_latent_vectors)

    stop = start + batch_size
    real_images = x_train[start:stop]
    combined_images = np.concatenate([generated_images, real_images])

    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    labels += 0.05 * np.random.random(labels.shape)
    

    d_loss = discriminator.train_on_batch(combined_images, labels)

    random_latent_vectors = np.random.normal(size = (batch_size, latent_dim))
    misleading_targets = np.zeros((batch_size, 1))

    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)

    start += batch_size

    if start > len(x_train) - batch_size:
        start = 0
    
    if step % 100 == 0:
        gan.save_weights('gan.h5')

        print("\nstep: {}".format(step))
        print(' discriminator loss: {}'.format(d_loss))
        print(' adversarial loss: {}'.format(a_loss))

        img = image.array_to_img(generated_images[0] * 255., scale = False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        img = image.array_to_img(real_images[0] * 255., scale = False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))

# 학습이 좀 느리다.
# Out:
# step: 0
#  discriminator loss: 0.6844996213912964
#  adversarial loss: 0.6415631175041199
#
# step: 100
#  discriminator loss: 0.7487896084785461
#  adversarial loss: 3.477858066558838
#
# step: 200
#  discriminator loss: 0.7768775820732117
#  adversarial loss: 1.417003870010376
#
# step: 300
#  discriminator loss: 0.6988449096679688
#  adversarial loss: 0.7104567885398865
#
# step: 400
#  discriminator loss: 0.7256951928138733
#  adversarial loss: 0.7732572555541992
#
# step: 500
#  discriminator loss: 0.6879904866218567
#  adversarial loss: 0.7765907645225525
#
# step: 600
#  discriminator loss: 0.7015860080718994
#  adversarial loss: 0.72856605052948
#
# step: 700
#  discriminator loss: 0.6996934413909912
#  adversarial loss: 0.7514840960502625
#
# step: 800
#  discriminator loss: 0.7154317498207092
#  adversarial loss: 0.7761624455451965
#
# step: 900
#  discriminator loss: 0.7017395496368408
#  adversarial loss: 0.7343398928642273
#
# step: 1000
#  discriminator loss: 0.702872633934021
#  adversarial loss: 0.759105384349823
#
# step: 1100
#  discriminator loss: 0.7132337689399719
#  adversarial loss: 0.7435416579246521
#
# step: 1200
#  discriminator loss: 0.688103199005127
#  adversarial loss: 0.7799863815307617
#
# step: 1300
#  discriminator loss: 0.6901213526725769
#  adversarial loss: 0.7315827012062073
#
# step: 1400
#  discriminator loss: 0.7088963389396667
#  adversarial loss: 0.7535656094551086
#
# step: 1500
#  discriminator loss: 0.7037383317947388
#  adversarial loss: 0.7619422674179077
#
# step: 1600
#  discriminator loss: 0.6932088136672974
#  adversarial loss: 0.7523788213729858
#
# step: 1700
#  discriminator loss: 0.795167863368988
#  adversarial loss: 1.1850519180297852
#
# step: 1800
#  discriminator loss: 0.7862639427185059
#  adversarial loss: 0.7585934400558472
#
# step: 1900
#  discriminator loss: 0.7043511271476746
#  adversarial loss: 0.7430844306945801
#
# step: 2000
#  discriminator loss: 0.7101562023162842
#  adversarial loss: 0.7554671764373779
#
# step: 2100
#  discriminator loss: 0.6759445071220398
#  adversarial loss: 0.7467456459999084
#
# step: 2200
#  discriminator loss: 0.7079321146011353
#  adversarial loss: 0.715545654296875
#
# step: 2300
#  discriminator loss: 0.7126461267471313
#  adversarial loss: 0.6502639055252075
#
# step: 2400
#  discriminator loss: 0.7058875560760498
#  adversarial loss: 0.7658134698867798
#
# step: 2500
#  discriminator loss: 0.7128643989562988
#  adversarial loss: 0.7562689781188965
#
# step: 2600
#  discriminator loss: 0.6817015409469604
#  adversarial loss: 0.739965558052063
#
# step: 2700
#  discriminator loss: 0.6927059888839722
#  adversarial loss: 0.7365732192993164
#
# step: 2800
#  discriminator loss: 0.6958805322647095
#  adversarial loss: 0.7293738126754761
#
# step: 2900
#  discriminator loss: 0.6839755773544312
#  adversarial loss: 0.7145534157752991
#
# step: 3000
#  discriminator loss: 0.6960769295692444
#  adversarial loss: 0.788175642490387
#
# step: 3100
#  discriminator loss: 0.7010102272033691
#  adversarial loss: 0.7354007959365845
#
# step: 3200
#  discriminator loss: 0.689014732837677
#  adversarial loss: 0.7616757154464722
#
# step: 3300
#  discriminator loss: 0.692182183265686
#  adversarial loss: 0.7506678104400635
#
# step: 3400
#  discriminator loss: 0.7026891112327576
#  adversarial loss: 0.7212573289871216
#
# step: 3500
#  discriminator loss: 0.6869354248046875
#  adversarial loss: 0.7273811101913452
#
# step: 3600
#  discriminator loss: 0.6997649073600769
#  adversarial loss: 0.7587078809738159
#
# step: 3700
#  discriminator loss: 0.6924089193344116
#  adversarial loss: 0.8014291524887085
#
# step: 3800
#  discriminator loss: 0.6870388984680176
#  adversarial loss: 0.7369850873947144
#
# step: 3900
#  discriminator loss: 0.8533018231391907
#  adversarial loss: 0.7974010705947876
#
# step: 4000
#  discriminator loss: 0.7024813890457153
#  adversarial loss: 0.7729591131210327
#
# step: 4100
#  discriminator loss: 0.7096036076545715
#  adversarial loss: 0.7080410718917847
#
# step: 4200
#  discriminator loss: 0.6675845980644226
#  adversarial loss: 0.8457886576652527
#
# step: 4300
#  discriminator loss: 0.8777128458023071
#  adversarial loss: 0.9835726022720337
#
# step: 4400
#  discriminator loss: 0.723922073841095
#  adversarial loss: 0.9172865152359009
#
# step: 4500
#  discriminator loss: 0.6992474794387817
#  adversarial loss: 0.7682411074638367
#
# step: 4600
#  discriminator loss: 0.6935010552406311
#  adversarial loss: 0.7370761036872864
#
# step: 4700
#  discriminator loss: 0.6913349628448486
#  adversarial loss: 0.7020739912986755
#
# step: 4800
#  discriminator loss: 0.699028730392456
#  adversarial loss: 0.731505274772644
#
# step: 4900
#  discriminator loss: 0.6877222061157227
#  adversarial loss: 0.763081431388855
#
# step: 5000
#  discriminator loss: 0.679651141166687
#  adversarial loss: 0.757789134979248
#
# step: 5100
#  discriminator loss: 0.7063209414482117
#  adversarial loss: 0.7718147039413452
#
# step: 5200
#  discriminator loss: 0.6919072866439819
#  adversarial loss: 0.7777999639511108
#
# step: 5300
#  discriminator loss: 0.7491011023521423
#  adversarial loss: 0.7980738282203674
#
# step: 5400
#  discriminator loss: 0.6962156295776367
#  adversarial loss: 0.7157489657402039
#
# step: 5500
#  discriminator loss: 0.7809202075004578
#  adversarial loss: 0.8037900924682617
#
# step: 5600
#  discriminator loss: 0.6766610145568848
#  adversarial loss: 0.7202402949333191
#
# step: 5700
#  discriminator loss: 0.6779741048812866
#  adversarial loss: 0.8683834075927734
#
# step: 5800
#  discriminator loss: 0.7074717283248901
#  adversarial loss: 0.8831764459609985
#
# step: 5900
#  discriminator loss: 0.6808198690414429
#  adversarial loss: 0.6405912637710571
#
# step: 6000
#  discriminator loss: 0.6964573860168457
#  adversarial loss: 0.7583309412002563
#
# step: 6100
#  discriminator loss: 0.6763166189193726
#  adversarial loss: 0.6965409517288208
#
# step: 6200
#  discriminator loss: 0.7029683589935303
#  adversarial loss: 0.8010839223861694
#
# step: 6300
#  discriminator loss: 0.6770897507667542
#  adversarial loss: 0.757215142250061
#
# step: 6400
#  discriminator loss: 0.6904736161231995
#  adversarial loss: 0.6902515292167664
#
# step: 6500
#  discriminator loss: 0.6691092252731323
#  adversarial loss: 0.9820381999015808
#
# step: 6600
#  discriminator loss: 0.6518657207489014
#  adversarial loss: 0.7824075818061829
#
# step: 6700
#  discriminator loss: 0.7087923288345337
#  adversarial loss: 0.9002300500869751
#
# step: 6800
#  discriminator loss: 0.7194526791572571
#  adversarial loss: 0.7956466674804688
#
# step: 6900
#  discriminator loss: 0.6828535199165344
#  adversarial loss: 0.670007586479187
#
# step: 7000
#  discriminator loss: 0.6632285118103027
#  adversarial loss: 0.7366426587104797
#
# step: 7100
#  discriminator loss: 0.6894680261611938
#  adversarial loss: 0.7534183263778687
#
# step: 7200
#  discriminator loss: 0.7419341802597046
#  adversarial loss: 0.940048336982727
#
# step: 7300
#  discriminator loss: 0.666404664516449
#  adversarial loss: 0.7870854735374451
#
# step: 7400
#  discriminator loss: 0.6729835271835327
#  adversarial loss: 0.7613029479980469
#
# step: 7500
#  discriminator loss: 0.6680610775947571
#  adversarial loss: 0.7002648115158081
#
# step: 7600
#  discriminator loss: 0.665229320526123
#  adversarial loss: 0.7965818643569946
#
# step: 7700
#  discriminator loss: 0.700559139251709
#  adversarial loss: 0.7271285653114319
#
# step: 7800
#  discriminator loss: 0.6549221277236938
#  adversarial loss: 0.889335036277771
#
# step: 7900
#  discriminator loss: 0.8012830018997192
#  adversarial loss: 0.662535548210144
#
# step: 8000
#  discriminator loss: 0.6872872114181519
#  adversarial loss: 0.8064268827438354
#
# step: 8100
#  discriminator loss: 0.6985615491867065
#  adversarial loss: 0.8112434148788452
#
# step: 8200
#  discriminator loss: 0.6792386770248413
#  adversarial loss: 0.8045150637626648
#
# step: 8300
#  discriminator loss: 0.6614309549331665
#  adversarial loss: 0.7629408836364746
#
# step: 8400
#  discriminator loss: 0.7311311960220337
#  adversarial loss: 1.0164916515350342
#
# step: 8500
#  discriminator loss: 0.6756845712661743
#  adversarial loss: 0.8017829060554504
#
# step: 8600
#  discriminator loss: 0.6465497016906738
#  adversarial loss: 0.8113256692886353
#
# step: 8700
#  discriminator loss: 0.7167769074440002
#  adversarial loss: 0.7167879343032837
#
# step: 8800
#  discriminator loss: 0.6900817155838013
#  adversarial loss: 0.7823513746261597
#
# step: 8900
#  discriminator loss: 0.6865321397781372
#  adversarial loss: 0.7609050869941711
#
# step: 9000
#  discriminator loss: 0.6534413695335388
#  adversarial loss: 0.7024029493331909
#
# step: 9100
#  discriminator loss: 0.7620154023170471
#  adversarial loss: 0.8245857954025269
#
# step: 9200
#  discriminator loss: 0.7198545336723328
#  adversarial loss: 1.1063607931137085
#
# step: 9300
#  discriminator loss: 0.7316612005233765
#  adversarial loss: 0.8200518488883972
#
# step: 9400
#  discriminator loss: 0.6687473654747009
#  adversarial loss: 0.7484059929847717
#
# step: 9500
#  discriminator loss: 0.6685155630111694
#  adversarial loss: 0.8039658665657043
#
# step: 9600
#  discriminator loss: 0.7142326831817627
#  adversarial loss: 0.7653580904006958
#
# step: 9700
#  discriminator loss: 0.6703392863273621
#  adversarial loss: 0.8007013201713562
#
# step: 9800
#  discriminator loss: 0.7021512985229492
#  adversarial loss: 0.7077173590660095
#
# step: 9900
#  discriminator loss: 0.7152881622314453
#  adversarial loss: 0.7382728457450867

# %% [markdown]
# #### 이미지 생성을 통한 시각화

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# - 잠재 공간에서 랜덤한 포인트를 샘플링

# %%
random_latent_vectors = np.random.normal(size = (10, latent_dim))

# %% [markdown]
# - 가짜 이미지로 디코딩

# %%
generated_images = generator.predict(random_latent_vectors)

# %%
print(generated_images.shape)
# Out:
# (10, 32, 32, 3)

# %%
plt.figure(figsize = (20, 8))

for i in range(generated_images.shape[0]):

    plt.subplot(2, 5, i + 1)
    img = image.array_to_img(generated_images[i] * 255., scale = False)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])

plt.show()
