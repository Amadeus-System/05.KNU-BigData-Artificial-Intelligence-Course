# %% [markdown]
# ## CNN 스팸 메일 분류

# %% [markdown]
# ### 데이터 로드 및 전처리

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# * https://raw.githubusercontent.com/mohitgupta-omg/Kaggle-SMS-Spam-Collection-Dataset-/master/spam.csv

# %%
import urllib.request

urllib.request.urlretrieve("https://raw.githubusercontent.com/mohitgupta-omg/Kaggle-SMS-Spam-Collection-Dataset-/master/spam.csv",
                           filename = 'spam.csv')
data = pd.read_csv("spam.csv", encoding = 'latin-1')
print(len(data))
# Out:
# 5572

# %%
data
# Out:
#         v1  ... Unnamed: 4
# 0      ham  ...        NaN
# 1      ham  ...        NaN
# 2     spam  ...        NaN
# 3      ham  ...        NaN
# 4      ham  ...        NaN
# ...    ...  ...        ...
# 5567  spam  ...        NaN
# 5568   ham  ...        NaN
# 5569   ham  ...        NaN
# 5570   ham  ...        NaN
# 5571   ham  ...        NaN
#
# [5572 rows x 5 columns]

# %%
del data['Unnamed: 2']
del data['Unnamed: 3']
del data['Unnamed: 4']

data['v1'] = data['v1'].replace(['ham', 'spam'], [0, 1])
data[:10]
# Out:
#    v1                                                 v2
# 0   0  Go until jurong point, crazy.. Available only ...
# 1   0                      Ok lar... Joking wif u oni...
# 2   1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   0  U dun say so early hor... U c already then say...
# 4   0  Nah I don't think he goes to usf, he lives aro...
# 5   1  FreeMsg Hey there darling it's been 3 week's n...
# 6   0  Even my brother is not like to speak with me. ...
# 7   0  As per your request 'Melle Melle (Oru Minnamin...
# 8   1  WINNER!! As a valued network customer you have...
# 9   1  Had your mobile 11 months or more? U R entitle...

# %%
data.drop_duplicates(subset = ['v2'], inplace = True)
len(data)
# Out:
# 5169

# %%
data['v1'].value_counts().plot(kind = 'bar')

# %%
data.groupby('v1').size().reset_index(name = 'count')
# Out:
#    v1  count
# 0   0   4516
# 1   1    653

# %%
X_data = data['v2']
y_data = data['v1']

# %%
vocab_size = 1000
tokenizer = Tokenizer(num_words = vocab_size)
tokenizer.fit_on_texts(X_data)
sequences = tokenizer.texts_to_sequences(X_data)

# %%
sequences[:5]
# Out:
# [[47, 433, 780, 705, 662, 64, 8, 94, 121, 434, 142, 68, 57, 137],
#  [49, 306, 435, 6],
#  [53,
#   537,
#   8,
#   20,
#   4,
#   934,
#   2,
#   220,
#   706,
#   267,
#   70,
#   2,
#   2,
#   359,
#   537,
#   604,
#   82,
#   436,
#   185,
#   707,
#   437],
#  [6, 226, 152, 23, 347, 6, 138, 145, 56, 152],
#  [935, 1, 97, 96, 69, 453, 2, 877, 69, 198, 105, 438]]

# %%
X_data = sequences

print("메일 최대 길이: {}".format(max(len(l) for l in X_data)))
print("메일 평균 길이: {}".format((sum(map(len, X_data)) / len(X_data))))
# Out:
# 메일 최대 길이: 172
# 메일 평균 길이: 12.566840781582512

# %%
plt.hist([len(s) for s in X_data], bins = 50)
plt.xlabel("Length of Samples")
plt.ylabel("Number of Samples")
plt.show()

# %%
max_len = 60
data = pad_sequences(X_data, maxlen = max_len)
print(data.shape)
# Out:
# (5169, 60)

# %%
n_train = int(len(sequences) * 0.8)
n_test  = int(len(sequences) - n_train)

print(n_train)
print(n_test)
# Out:
# 4135
# 1034

# %%
X_train = data[:n_train]
y_train = np.array(y_data[:n_train])
X_test = data[n_train:]
y_test = np.array(y_data[n_train:])

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (4135, 60)
# (4135,)
# (1034, 60)
# (1034,)

# %% [markdown]
# ### 모델 구성

# %%
from tensorflow.keras.layers import Dense, Conv1D, GlobalMaxPooling1D, Embedding, Dropout, MaxPool1D
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
model = Sequential()

model.add(Embedding(vocab_size, 32))
model.add(Dropout(0.2))
model.add(Conv1D(32, 5, strides=1, padding = 'valid', activation= 'relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(64, activation = 'relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation = 'sigmoid'))
model.summary()

model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
              metrics = ['acc'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 32)          32000
# _________________________________________________________________
# dropout (Dropout)            (None, None, 32)          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 32)          5152
# _________________________________________________________________
# global_max_pooling1d (Global (None, 32)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2112
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 39,329
# Trainable params: 39,329
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 3)
mc = ModelCheckpoint('best_model.h5', monitor = 'val_acc', mode = 'max',
                     verbose = 1, save_best_only=True)

# %% [markdown]
# ### 모델 학습

# %%
hist = model.fit(X_train, y_train,
                 epochs = 10,
                 batch_size = 64,
                 validation_split = 0.2,
                 callbacks = [es, mc])
# Out:
# Epoch 1/10
# 52/52 [==============================] - ETA: 0s - loss: 0.5002 - acc: 0.8473
# Epoch 00001: val_acc improved from -inf to 0.87304, saving model to best_model.h5
# 52/52 [==============================] - 1s 12ms/step - loss: 0.5002 - acc: 0.8473 - val_loss: 0.3767 - val_acc: 0.8730
# Epoch 2/10
# 48/52 [==========================>...] - ETA: 0s - loss: 0.3830 - acc: 0.8662
# Epoch 00002: val_acc did not improve from 0.87304
# 52/52 [==============================] - 0s 7ms/step - loss: 0.3744 - acc: 0.8697 - val_loss: 0.3202 - val_acc: 0.8730
# Epoch 3/10
# 46/52 [=========================>....] - ETA: 0s - loss: 0.2265 - acc: 0.9069
# Epoch 00003: val_acc improved from 0.87304 to 0.97823, saving model to best_model.h5
# 52/52 [==============================] - 0s 7ms/step - loss: 0.2121 - acc: 0.9148 - val_loss: 0.1024 - val_acc: 0.9782
# Epoch 4/10
# 46/52 [=========================>....] - ETA: 0s - loss: 0.0696 - acc: 0.9827
# Epoch 00004: val_acc improved from 0.97823 to 0.98065, saving model to best_model.h5
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0691 - acc: 0.9828 - val_loss: 0.0555 - val_acc: 0.9807
# Epoch 5/10
# 47/52 [==========================>...] - ETA: 0s - loss: 0.0396 - acc: 0.9897
# Epoch 00005: val_acc did not improve from 0.98065
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0410 - acc: 0.9894 - val_loss: 0.0494 - val_acc: 0.9807
# Epoch 6/10
# 45/52 [========================>.....] - ETA: 0s - loss: 0.0252 - acc: 0.9910
# Epoch 00006: val_acc improved from 0.98065 to 0.98186, saving model to best_model.h5
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0255 - acc: 0.9915 - val_loss: 0.0454 - val_acc: 0.9819
# Epoch 7/10
# 46/52 [=========================>....] - ETA: 0s - loss: 0.0192 - acc: 0.9946
# Epoch 00007: val_acc did not improve from 0.98186
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0180 - acc: 0.9952 - val_loss: 0.0486 - val_acc: 0.9819
# Epoch 8/10
# 45/52 [========================>.....] - ETA: 0s - loss: 0.0111 - acc: 0.9986
# Epoch 00008: val_acc improved from 0.98186 to 0.98307, saving model to best_model.h5
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0104 - acc: 0.9988 - val_loss: 0.0486 - val_acc: 0.9831
# Epoch 9/10
# 48/52 [==========================>...] - ETA: 0s - loss: 0.0077 - acc: 0.9987
# Epoch 00009: val_acc improved from 0.98307 to 0.98428, saving model to best_model.h5
# 52/52 [==============================] - 0s 7ms/step - loss: 0.0074 - acc: 0.9988 - val_loss: 0.0515 - val_acc: 0.9843
# Epoch 00009: early stopping

# %% [markdown]
# ### 시각화

# %%
loss = hist.history['loss']
val_loss = hist.history['val_loss']
acc = hist.history['acc']
val_acc = hist.history['val_acc']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'b--', label = 'training loss')
plt.plot(epochs, val_loss, 'r:', label = 'validation loss')
plt.grid()
plt.legend()

plt.figure()
plt.plot(epochs, acc, 'b--', label = 'training acc')
plt.plot(epochs, val_acc, 'r:', label = 'validation acc')
plt.grid()
plt.legend()

plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0600 - acc: 0.9836
# [0.060029614716768265, 0.9835590124130249]
