# %% [markdown]
# # 케라스 CNN CIFAR 10
#
# - 50,000개의 학습데이터, 10,000개의 테스트 데이터로 구성
#
# - 데이터 복잡도가 MNIST보다 훨씬 높은 특징이 있음
#   - 신경망이 특징을 검출하기 어려움
#
#   <img src="https://www.researchgate.net/profile/Jean_Elsner/publication/329969195/figure/fig1/AS:708799606317059@1546002403551/Images-from-the-CIFAR-10-13-dataset-and-their-corresponding-classes-CIFAR-10.ppm">

# %% [markdown]
# ### modules import

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Input, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
plt.style.use('seaborn-white')

import numpy as np

# %% [markdown]
# ### 데이터 로드 및 전처리

# %%
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()

print(x_train_full.shape, y_train_full.shape)
print(x_test.shape, y_test.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 6s 0us/step
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)

# %%
print(y_test[5])
# Out:
# [6]

# %%
np.random.seed(777)

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'sheep', 'truck']

sample_size = 9
random_idx = np.random.randint(60000, size = sample_size)

plt.figure(figsize = (5, 5))
for i, idx in enumerate(random_idx):
    plt.subplot(3, 3, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train_full[i])
    plt.xlabel(class_names[int(y_train_full[i])])

plt.show()

# %%
x_mean = np.mean(x_train_full, axis = (0, 1, 2))
x_std = np.std(x_train_full, axis = (0, 1, 2))

x_train_full = (x_train_full - x_mean) / x_std
x_test = (x_test - x_mean) / x_std

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.3)

# %%
print(x_train.shape)
print(y_train.shape)

print(x_val.shape)
print(y_val.shape)

print(x_test.shape)
print(y_test.shape)
# Out:
# (35000, 32, 32, 3)
# (35000, 1)
# (15000, 32, 32, 3)
# (15000, 1)
# (10000, 32, 32, 3)
# (10000, 1)

# %% [markdown]
# ### 모델 구성 및 컴파일

# %%
def model_build():

    model = Sequential()

    input = Input(shape = (32, 32, 3))

    output = Conv2D(filters = 32, kernel_size = 3, padding = 'same', activation = 'relu')(input)
    output = MaxPool2D(pool_size=(2, 2), strides = 2, padding = 'same')(output)

    output = Conv2D(filters = 64, kernel_size = 3, padding = 'same', activation = 'relu')(output)
    output = MaxPool2D(pool_size=(2, 2), strides = 2, padding = 'same')(output)

    output = Conv2D(filters = 128, kernel_size = 3, padding = 'same', activation = 'relu')(output)
    output = MaxPool2D(pool_size=(2, 2), strides = 2, padding = 'same')(output)

    output = Flatten()(output)
    output = Dense(256, activation = 'relu')(output)
    output = Dense(128, activation = 'relu')(output)
    output = Dense(10, activation = 'softmax')(output)

    model = Model(inputs = [input],
                  outputs = output)
    
    model.compile(optimizer = Adam(learning_rate = 1e-4),
                  loss = 'sparse_categorical_crossentropy',
                  metrics = ['accuracy'])
    
    return model

# %%
model = model_build()
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 651,978
# Trainable params: 651,978
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습 및 평가
# - [런타임]에서 GPU 설정

# %%
hist = model.fit(x_train, y_train,
                 epochs = 30,
                 validation_data = (x_val, y_val),
                 batch_size = 256)
# Out:
# Epoch 1/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.8742 - accuracy: 0.3393 - val_loss: 1.6149 - val_accuracy: 0.4191
# Epoch 2/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.5058 - accuracy: 0.4656 - val_loss: 1.4434 - val_accuracy: 0.4913
# Epoch 3/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.3810 - accuracy: 0.5089 - val_loss: 1.3576 - val_accuracy: 0.5147
# Epoch 4/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.3077 - accuracy: 0.5402 - val_loss: 1.2918 - val_accuracy: 0.5413
# Epoch 5/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.2523 - accuracy: 0.5596 - val_loss: 1.2393 - val_accuracy: 0.5631
# Epoch 6/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.1960 - accuracy: 0.5821 - val_loss: 1.2160 - val_accuracy: 0.5666
# Epoch 7/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.1479 - accuracy: 0.6002 - val_loss: 1.1560 - val_accuracy: 0.5975
# Epoch 8/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.1128 - accuracy: 0.6137 - val_loss: 1.1509 - val_accuracy: 0.5970
# Epoch 9/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.0737 - accuracy: 0.6264 - val_loss: 1.1366 - val_accuracy: 0.5947
# Epoch 10/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.0441 - accuracy: 0.6381 - val_loss: 1.1119 - val_accuracy: 0.6109
# Epoch 11/30
# 137/137 [==============================] - 2s 11ms/step - loss: 1.0099 - accuracy: 0.6502 - val_loss: 1.0503 - val_accuracy: 0.6326
# Epoch 12/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.9879 - accuracy: 0.6588 - val_loss: 1.0598 - val_accuracy: 0.6303
# Epoch 13/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.9553 - accuracy: 0.6699 - val_loss: 1.0373 - val_accuracy: 0.6345
# Epoch 14/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.9372 - accuracy: 0.6798 - val_loss: 1.0354 - val_accuracy: 0.6363
# Epoch 15/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.9102 - accuracy: 0.6873 - val_loss: 1.0036 - val_accuracy: 0.6467
# Epoch 16/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.8933 - accuracy: 0.6928 - val_loss: 0.9797 - val_accuracy: 0.6611
# Epoch 17/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.8742 - accuracy: 0.7013 - val_loss: 0.9878 - val_accuracy: 0.6599
# Epoch 18/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.8512 - accuracy: 0.7073 - val_loss: 0.9808 - val_accuracy: 0.6573
# Epoch 19/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.8391 - accuracy: 0.7113 - val_loss: 0.9500 - val_accuracy: 0.6695
# Epoch 20/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.8200 - accuracy: 0.7190 - val_loss: 0.9589 - val_accuracy: 0.6653
# Epoch 21/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.8018 - accuracy: 0.7266 - val_loss: 0.9365 - val_accuracy: 0.6795
# Epoch 22/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.7855 - accuracy: 0.7335 - val_loss: 0.9378 - val_accuracy: 0.6731
# Epoch 23/30
# 137/137 [==============================] - 2s 12ms/step - loss: 0.7651 - accuracy: 0.7382 - val_loss: 0.9423 - val_accuracy: 0.6727
# Epoch 24/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.7590 - accuracy: 0.7408 - val_loss: 0.9243 - val_accuracy: 0.6807
# Epoch 25/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.7443 - accuracy: 0.7474 - val_loss: 0.9254 - val_accuracy: 0.6806
# Epoch 26/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.7259 - accuracy: 0.7551 - val_loss: 0.9152 - val_accuracy: 0.6874
# Epoch 27/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.7036 - accuracy: 0.7620 - val_loss: 0.8944 - val_accuracy: 0.6973
# Epoch 28/30
# 137/137 [==============================] - 2s 11ms/step - loss: 0.6918 - accuracy: 0.7647 - val_loss: 0.8932 - val_accuracy: 0.6931
# Epoch 29/30
# 137/137 [==============================] - 2s 12ms/step - loss: 0.6836 - accuracy: 0.7677 - val_loss: 0.9093 - val_accuracy: 0.6894
# Epoch 30/30
# 137/137 [==============================] - 2s 12ms/step - loss: 0.6665 - accuracy: 0.7743 - val_loss: 0.8932 - val_accuracy: 0.6966

# %% [markdown]
# ### 학습 과정 시각화

# %%
plt.figure(figsize = (12, 4))

plt.subplot(1, 2, 1)
plt.plot(hist.history['loss'], 'b--', label = 'loss')
plt.plot(hist.history['val_loss'], 'r:', label = 'val loss')
plt.xlabel("Epochs")
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(hist.history['accuracy'], 'b--', label = 'acc')
plt.plot(hist.history['val_accuracy'], 'r:', label = 'val acc')
plt.xlabel("Epochs")
plt.grid()
plt.legend()

plt.show()

# %% [markdown]
# - 해당 모델은 성능이 좋지 않음
# - 규제화, 드롭아웃 등 과대적합을 방지하는 기술 필요

# %%
def model_build2():

    model = Sequential()

    input = Input(shape = (32, 32, 3))

    output = Conv2D(filters = 32, kernel_size = 3, padding = 'same', activation = 'relu')(input)
    output = BatchNormalization()(output)
    output = MaxPool2D(pool_size=(2, 2), strides = 2, padding = 'same')(output)

    output = Conv2D(filters = 64, kernel_size = 3, padding = 'same', activation = 'relu')(output)
    output = BatchNormalization()(output)
    output = MaxPool2D(pool_size=(2, 2), strides = 2, padding = 'same')(output)

    output = Conv2D(filters = 128, kernel_size = 3, padding = 'same', activation = 'relu')(output)
    output = BatchNormalization()(output)
    output = MaxPool2D(pool_size=(2, 2), strides = 2, padding = 'same')(output)
    output = Dropout(0.5)(output)


    output = Flatten()(output)
    output = Dense(256, activation = 'relu')(output)
    output = Dropout(0.5)(output)
    output = Dense(128, activation = 'relu')(output)
    output = Dense(10, activation = 'softmax')(output)

    model = Model(inputs = [input],
                  outputs = output)
    
    model.compile(optimizer = Adam(learning_rate = 1e-4),
                  loss = 'sparse_categorical_crossentropy',
                  metrics = ['accuracy'])
    
    return model

# %%
model2 = model_build2()
model2.summary()
# Out:
# Model: "functional_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 128)         73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_11 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 652,874
# Trainable params: 652,426
# Non-trainable params: 448
# _________________________________________________________________

# %% [markdown]
# ### 모델 학습 및 평가
# - [런타임]에서 GPU 설정

# %%
hist2 = model2.fit(x_train, y_train,
                 epochs = 30,
                 validation_data = (x_val, y_val),
                 batch_size = 256)
# Out:
# Epoch 1/30
# 137/137 [==============================] - 2s 16ms/step - loss: 2.5715 - accuracy: 0.1996 - val_loss: 2.1207 - val_accuracy: 0.1929
# Epoch 2/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.9965 - accuracy: 0.2893 - val_loss: 1.8450 - val_accuracy: 0.3252
# Epoch 3/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.8281 - accuracy: 0.3436 - val_loss: 1.6279 - val_accuracy: 0.4211
# Epoch 4/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.7206 - accuracy: 0.3777 - val_loss: 1.5113 - val_accuracy: 0.4679
# Epoch 5/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.6360 - accuracy: 0.4042 - val_loss: 1.4344 - val_accuracy: 0.4885
# Epoch 6/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.5730 - accuracy: 0.4254 - val_loss: 1.3950 - val_accuracy: 0.4999
# Epoch 7/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.5106 - accuracy: 0.4494 - val_loss: 1.3435 - val_accuracy: 0.5181
# Epoch 8/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.4645 - accuracy: 0.4682 - val_loss: 1.3150 - val_accuracy: 0.5319
# Epoch 9/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.4266 - accuracy: 0.4840 - val_loss: 1.2820 - val_accuracy: 0.5433
# Epoch 10/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.3890 - accuracy: 0.4962 - val_loss: 1.2485 - val_accuracy: 0.5563
# Epoch 11/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.3591 - accuracy: 0.5062 - val_loss: 1.2289 - val_accuracy: 0.5612
# Epoch 12/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.3266 - accuracy: 0.5207 - val_loss: 1.1907 - val_accuracy: 0.5779
# Epoch 13/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.3015 - accuracy: 0.5283 - val_loss: 1.1707 - val_accuracy: 0.5834
# Epoch 14/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.2679 - accuracy: 0.5445 - val_loss: 1.1434 - val_accuracy: 0.5954
# Epoch 15/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.2370 - accuracy: 0.5522 - val_loss: 1.1159 - val_accuracy: 0.6085
# Epoch 16/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.2142 - accuracy: 0.5616 - val_loss: 1.1056 - val_accuracy: 0.6143
# Epoch 17/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.1938 - accuracy: 0.5694 - val_loss: 1.0823 - val_accuracy: 0.6211
# Epoch 18/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.1661 - accuracy: 0.5838 - val_loss: 1.0537 - val_accuracy: 0.6285
# Epoch 19/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.1466 - accuracy: 0.5878 - val_loss: 1.0506 - val_accuracy: 0.6301
# Epoch 20/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.1208 - accuracy: 0.6023 - val_loss: 1.0276 - val_accuracy: 0.6407
# Epoch 21/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.1027 - accuracy: 0.6077 - val_loss: 1.0123 - val_accuracy: 0.6421
# Epoch 22/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.0884 - accuracy: 0.6123 - val_loss: 1.0022 - val_accuracy: 0.6478
# Epoch 23/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.0588 - accuracy: 0.6224 - val_loss: 0.9803 - val_accuracy: 0.6547
# Epoch 24/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.0443 - accuracy: 0.6259 - val_loss: 0.9743 - val_accuracy: 0.6603
# Epoch 25/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.0313 - accuracy: 0.6330 - val_loss: 0.9520 - val_accuracy: 0.6665
# Epoch 26/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.0152 - accuracy: 0.6417 - val_loss: 0.9531 - val_accuracy: 0.6653
# Epoch 27/30
# 137/137 [==============================] - 2s 14ms/step - loss: 1.0072 - accuracy: 0.6414 - val_loss: 0.9388 - val_accuracy: 0.6724
# Epoch 28/30
# 137/137 [==============================] - 2s 14ms/step - loss: 0.9815 - accuracy: 0.6522 - val_loss: 0.9337 - val_accuracy: 0.6725
# Epoch 29/30
# 137/137 [==============================] - 2s 14ms/step - loss: 0.9723 - accuracy: 0.6548 - val_loss: 0.9191 - val_accuracy: 0.6796
# Epoch 30/30
# 137/137 [==============================] - 2s 14ms/step - loss: 0.9570 - accuracy: 0.6605 - val_loss: 0.9075 - val_accuracy: 0.6805

# %% [markdown]
# ### 학습 과정 시각화

# %%
plt.figure(figsize = (12, 4))

plt.subplot(1, 2, 1)
plt.plot(hist2.history['loss'], 'b--', label = 'loss')
plt.plot(hist2.history['val_loss'], 'r:', label = 'val loss')
plt.xlabel("Epochs")
plt.grid()
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(hist2.history['accuracy'], 'b--', label = 'acc')
plt.plot(hist2.history['val_accuracy'], 'r:', label = 'val acc')
plt.xlabel("Epochs")
plt.grid()
plt.legend()

plt.show()

# %%
model2.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.9076 - accuracy: 0.6853
# [0.9076284170150757, 0.6852999925613403]
