# %% [markdown]
# # 네이버 검색 API 서비스

# %% [markdown]
# ## 네이버 서비스 API 신청
#
# 1. 네이버 개발자센터: https://developers.naver.com/products/search/
# 2. 어플리케이션 등록
# 3. 클라이언트 ID/SECRET 확인

# %% [markdown]
# ## NAVER 서비스 API 종류
# | 항목 | 주소                                         |
# |------|----------------------------------------------|
# |블로그| https://openapi.naver.com/v1/search/blog.json |
# |뉴스　| https://openapi.naver.com/v1/search/news.json |
# | 책　 | https://openapi.naver.com/v1/search/book.json|
# | 성인 검색어 판별|　https://openapi.naver.com/v1/search/adult.json|
# | 백과사전| https://openapi.naver.com/v1/search/encyc.json|
# | 영화| https://openapi.naver.com/v1/search/movie.json|
# | 카페글 |https://openapi.naver.com/v1/search/cafearticle.json|
# | 지식in| https://openapi.naver.com/v1/search/kin.json|
# | 지역 | https://openapi.naver.com/v1/search/local.json|
# | 오타변환 | https://openapi.naver.com/v1/search/errata.json|
# | 웹문서 | https://openapi.naver.com/v1/search/webkr.json|
# | 이미지 | https://openapi.naver.com/v1/search/image.json|
# | 쇼핑 | https://openapi.naver.com/v1/search/shop.json|
# | 전문자료 | https://openapi.naver.com/v1/search/doc.json|

# %% [markdown]
# ## 네이버 웹문서 검색 API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re # regular expression : 정규식

client_id = "zZOYjR1jsi32j2DblygC"
client_secret = "a84jIfkyhn"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000


# pandas 데이터로 저장
web_df = pd.DataFrame(columns = ("Title", "Link", "Description"))


for start_index in range(start, end, display):

    url = "https://openapi.naver.com/v1/search/webkr?query=" + query \
          + "&display=" + str(display) \
          + "&start=" + str(start_index)


    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode==200): # 200은 정상적으로 응답받았다는 코드
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']

        for item_index in range(0, len(items)):

            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            web_df.loc[idx] = [title, link, description]
            idx += 1
    else:
        print("Error Code:" + rescode)


web_df
# Out:
# 검색 질의: 컴퓨터
#                           Title  ...                                        Description
# 0                    컴퓨터 - 나무위키  ...  개인용 컴퓨터에 대한 내용은 PC 문서를 참조하십시오. 올해의 인물 (1980년대)...
# 1                          주연테크  ...  주연테크 회사소개 및 컴퓨터,PC,데스크탑,모니터,노트북,태블릿,TV,CCTV 등 ...
# 2                          TG삼보  ...                  컴퓨터, 모니터, 노트북 제조판매 등 제품소개, AS 안내.
# 3                        한글과컴퓨터  ...  한컴오피스, 씽크프리, 전자책, 앱북, 솔루션 제품 체험판, 뷰어 다운로드 및 고객...
# 4                  슈퍼컴퓨터 - 나무위키  ...  가장 빠른 슈퍼컴퓨터 연혁 4.2. 대한민국의 슈퍼컴퓨터 도입 4.2.1. 기상청 ...
# ..                          ...  ...                                                ...
# 195  공지사항 &gt;학부공지사항 &gt; 컴퓨터학부  ...  【 컴퓨터학부 현장실습(견학) 안내】 컴퓨터학부 조회 : 95 등록일 : 2019-...
# 196           컴퓨터학부 현장실습(견학) 안내  ...  【 컴퓨터학부 현장실습(견학) 안내】 컴퓨터학부 조회 : 495 등록일 : 2019...
# 197  공지사항 &gt;학부공지사항 &gt; 컴퓨터학부  ...  【 컴퓨터학부 특강안내 】 컴퓨터학부 조회 : 97 등록일 : 2019-11-21 ...
# ...

# %% [markdown]
# ## 네이버 지식iN 검색 API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re # regular expression : 정규식

client_id = "zZOYjR1jsi32j2DblygC"
client_secret = "a84jIfkyhn"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'sim' # 유사도


# pandas 데이터로 저장
kin_df = pd.DataFrame(columns = ("Title", "Link", "Description"))


for start_index in range(start, end, display):

    url = "https://openapi.naver.com/v1/search/kin?query=" + query \
          + "&display=" + str(display) \
          + "&start=" + str(start_index) \
          + "&sort=" + sort


    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode==200): # 200은 정상적으로 응답받았다는 코드
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']

        for item_index in range(0, len(items)):

            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            kin_df.loc[idx] = [title, link, description]
            idx += 1
    else:
        print("Error Code:" + rescode)


kin_df
# Out:
# 검색 질의: 컴퓨터
#               Title  ...                                        Description
# 0    학점은행제 컴퓨터공학..?  ...  안녕하세요 학점은행제 컴퓨터공학을 시작하려고 하는데요. 제가 직장인인데 학점은행제 ...
# 1     학점은행제 컴퓨터공학 좀  ...  제가 컴퓨터공학 분야로 알아보고 있는데 학점은행제 컴퓨터공학 쪽으로 가능한건가요? ...
# 2      학점은행제 컴퓨터공학*  ...  ... 그래서 학점은행제 컴퓨터공학 해보려고 하는데요. 직장 다니면서 학점은행제 컴...
# 3      학점은행제 컴퓨터공학을  ...  학점은행제 컴퓨터공학을 이수하면 학점은행제 컴퓨터공학 학위가 나오나요? 대학교가 아...
# 4           조립식컴퓨터랑  ...  조립식컴퓨터랑 그냥 컴퓨터랑 성능 면에서 차이가 있나요? 질문자님을 뵙게 되어 감사...
# ..              ...  ...                                                ...
# 995          컴퓨터 질문  ...  ... 확실하진않지만 컴퓨터를 바꿀수도잇어 질문합니다. 일단 저는 롤이라는 게임을합...
# 996        컴퓨터관련 학과  ...  컴퓨터관련 학과를 알아보는 고3입니다. 질문이 몇개 있는데 답변해주시면 감사하겠습니...
# 997  정보보호 영재와 컴퓨터학원  ...  이번에 컴퓨터공부(IT)에 관심이 있어 컴퓨터공부를 시작하려는 예비 고1입니다 이번...
# 998          컴퓨터 견적  ...  컴퓨터 견적 제가 이번에 컴퓨터를 사려고합니다. 그런데 정말 컴퓨터를 잘 모릅니다....
# 999       롤 렉없는 컴퓨터  ...  ... 렉전혀안걸리는 컴퓨터살려하는데 컴퓨터 회사하고 그회사에 롤렉안걸리는 컴퓨터 ...
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## 네이버 뉴스 검색 API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re # regular expression : 정규식

client_id = "zZOYjR1jsi32j2DblygC"
client_secret = "a84jIfkyhn"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'sim' # 유사도


# pandas 데이터로 저장
news_df = pd.DataFrame(columns = ("Title", "Original Link","Link", "Description",
                                 "Publication Date"))


for start_index in range(start, end, display):

    url = "https://openapi.naver.com/v1/search/news?query=" + query \
          + "&display=" + str(display) \
          + "&start=" + str(start_index) \
          + "&sort=" + sort


    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode==200): # 200은 정상적으로 응답받았다는 코드
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']

        for item_index in range(0, len(items)):

            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            original_link = items[item_index]['originallink']
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            pub_date = items[item_index]['pubDate']
            news_df.loc[idx] = [title, original_link, link, description, pub_date]
            idx += 1
    else:
        print("Error Code:" + rescode)


news_df
# Out:
# 검색 질의: 컴퓨터
#                                   Title  ...                 Publication Date
# 0       AP위성, 달 궤도선 탑재컴퓨터 및 탑재자료처리장치 납품  ...  Mon, 10 Aug 2020 09:16:00 +0900
# 1              한글과컴퓨터, 스타트업에 한컴오피스 무상공급  ...  Mon, 10 Aug 2020 09:50:00 +0900
# 2         한글과컴퓨터, 신생 스타트업 대상 한컴오피스 무상공급  ...  Mon, 10 Aug 2020 09:47:00 +0900
# 3       AP위성, 달 궤도선 탑재컴퓨터 및 탑재자료처리장치 납품  ...  Mon, 10 Aug 2020 08:58:00 +0900
# 4       한글과컴퓨터, 스타트업에 '한컴오피스' 1년 간 무상지원  ...  Mon, 10 Aug 2020 09:28:00 +0900
# ..                                  ...  ...                              ...
# 995        신한생명, 소외아동 위한 온라인 강의용 컴퓨터 지원  ...  Mon, 13 Apr 2020 10:03:00 +0900
# 996     한글과컴퓨터그룹-가평군, 체감형 스마트시티 조성 업무협력  ...  Tue, 12 May 2020 17:58:00 +0900
# 997       넥슨컴퓨터박물관, '코로나19' 확산 방지 임시 휴관  ...  Mon, 24 Feb 2020 16:38:00 +0900
# 998  강원랜드 복지재단, 온라인 개학에 컴퓨터지원 사업 앞당겨 실시  ...  Fri, 10 Apr 2020 13:25:00 +0900
# 999            뇌·컴퓨터 연결 꿈의 프로젝트 곧 현실화되나  ...  Wed, 05 Feb 2020 17:22:00 +0900
#
# ...

# %% [markdown]
# ## 네이버 블로그 검색 API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re # regular expression : 정규식

client_id = "zZOYjR1jsi32j2DblygC"
client_secret = "a84jIfkyhn"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'sim' # 유사도


# pandas 데이터로 저장
blog_df = pd.DataFrame(columns = ("Title", "Link", "Description", "Blogger Name", 
                                 "Blogger Link", "Post Date"))


for start_index in range(start, end, display):

    url = "https://openapi.naver.com/v1/search/blog?query=" + query \
          + "&display=" + str(display) \
          + "&start=" + str(start_index) \
          + "&sort=" + sort


    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode==200): # 200은 정상적으로 응답받았다는 코드
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']

        for item_index in range(0, len(items)):

            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            blogger_name = items[item_index]['bloggername']
            blogger_link = items[item_index]['bloggerlink']
            post_date = items[item_index]['postdate']
            blog_df.loc[idx] = [title, link, description, blogger_name, blogger_link,
                                post_date]
            idx += 1
    else:
        print("Error Code:" + rescode)


blog_df
# Out:
# 검색 질의: 컴퓨터
#                               Title  ... Post Date
# 0                    할수있다 컴퓨터공학과 편입  ...  20200808
# 1              국비지원컴퓨터학원 현명한 선택이 필수  ...  20200720
# 2                컴퓨터학원 국비지원으로 배웠어요!  ...  20200423
# 3    한성컴퓨터 가성비 노트북 올데이롱 TFX255S 사용기  ...  20200806
# 4             강남컴퓨터학원 전문가로 성장하는 과정!  ...  20200708
# ..                              ...  ...       ...
# 995               서울컴퓨터학원 수강료 알아보기!  ...  20200110
# 996         1만원대 초소형 컴퓨터 '아두이노' 나왔다  ...  20190522
# 997                       컴퓨터와 대화하기  ...  20200128
# 998       몬스타기어 컴퓨터스피커로 만족스럽게 사용해요.  ...  20200217
# 999       10세대 i9 프로세서로 꾸민 영상편집 컴퓨터  ...  20200623
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## 네이버 책 검색 API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re # regular expression : 정규식

client_id = "zZOYjR1jsi32j2DblygC"
client_secret = "a84jIfkyhn"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'sim' # 유사도


# pandas 데이터로 저장
book_df = pd.DataFrame(columns = ("Title", "Link", "Image", "Author",
                                  "Price", "Discount", "Publisher", 
                                  "ISBN", "Description", "Publication Date"))


for start_index in range(start, end, display):

    url = "https://openapi.naver.com/v1/search/book?query=" + query \
          + "&display=" + str(display) \
          + "&start=" + str(start_index) \
          + "&sort=" + sort


    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode==200): # 200은 정상적으로 응답받았다는 코드
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']

        for item_index in range(0, len(items)):

            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            image = items[item_index]['image']
            author = items[item_index]['author']
            price = items[item_index]['price']
            discount = items[item_index]['discount']
            publisher = items[item_index]['publisher']
            isbn = items[item_index]['isbn']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            pubdate = items[item_index]['pubdate']
            book_df.loc[idx] = [title, link, image, author, price, discount,
                                publisher, isbn, description, pubdate]
            idx += 1
    else:
        print("Error Code:" + rescode)


book_df
# Out:
# 검색 질의: 컴퓨터
#                                                  Title  ... Publication Date
# 0    시나공 총정리 컴퓨터활용능력 1급 필기 (핵심요약+기출문제+모의고사+암기프로그램+기...  ...         20190909
# 1                              시나공 컴퓨터활용능력 2급실기 (2020)  ...         20191008
# 2                              시나공 컴퓨터활용능력1급 실기 (2020)  ...         20191010
# 3    시나공 총정리 컴퓨터활용능력 2급 필기 (핵심요약+기출문제+모의고사+암기프로그램+기...  ...         20190909
# 4    시나공 컴퓨터활용능력 1급 필기 (필수암기집+동영상강의+암기프로그램+기출CBT,2020)  ...         20191028
# ..                                                 ...  ...              ...
# 995             컴퓨터 달인 되기 101가지 비법 (우리 부모님 컴퓨터 초보 탈출기)  ...         20090610
# 996                              미래컴퓨터를 줍다 2 (초갑질 기업물)  ...         20180320
# 997                         부모님의 첫번째 컴퓨터+인터넷 책 (윈도우 7)  ...         20110627
# 998                                [빅북] IoT 시대의 스마트컴퓨터  ...         20190109
# 999                                     슈퍼컴퓨터를 사랑한 슈퍼맨  ...         20150811
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## 네이버 영화 검색 API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re # regular expression : 정규식

client_id = "zZOYjR1jsi32j2DblygC"
client_secret = "a84jIfkyhn"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'sim' # 유사도


# pandas 데이터로 저장
movie_df = pd.DataFrame(columns = ("Title", "Link", "Image", "Subtitle",
                                  "Publication Date", "Director", "Actor",
                                   "User Rating"))


for start_index in range(start, end, display):

    url = "https://openapi.naver.com/v1/search/movie?query=" + query \
          + "&display=" + str(display) \
          + "&start=" + str(start_index) \
          + "&sort=" + sort


    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode==200): # 200은 정상적으로 응답받았다는 코드
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']

        for item_index in range(0, len(items)):

            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            image = items[item_index]['image']
            subtitle = items[item_index]['subtitle']
            pub_date = items[item_index]['pubDate']
            
            director = items[item_index]['director']
            actor = items[item_index]['actor']
            user_rating = items[item_index]['userRating']

            movie_df.loc[idx] = [title, link, image, subtitle, pub_date,
                                 director, actor, user_rating]
            idx += 1
    else:
        print("Error Code:" + rescode)


movie_df
# Out:
# 검색 질의: 아이언맨
#                    Title  ... User Rating
# 0        엘론 머스크: 리얼 아이언맨  ...        0.00
# 1                   아이언맨  ...        4.95
# 2     아이언맨 &amp; 캡틴 아메리카  ...        9.00
# 3                 아이언맨 3  ...        8.86
# 4    아이언 맨: 라이즈 오브 테크노보어  ...        3.28
# ..                   ...  ...         ...
# 125           인빈서블 아이언 맨  ...        7.24
# 126     특수공작원 아이언맨 - 시리즈  ...        7.63
# 127           특수공작원 아이언맨  ...        9.00
# 128                아이언 맨  ...        5.37
# 129                아이언 맨  ...        7.54
#
# [130 rows x 8 columns]

# %% [markdown]
# ## 네이버 쇼핑 검색 API

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
import pandas as pd
import json
import re # regular expression : 정규식

client_id = "zZOYjR1jsi32j2DblygC"
client_secret = "a84jIfkyhn"

query = urllib.parse.quote(input("검색 질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'sim' # 유사도


# pandas 데이터로 저장
shop_df = pd.DataFrame(columns = ("Title", "Link", "Image", "Low Price",
                                  "High Price", "Mall Name", "Product ID",
                                  "Product Type", "Maker", "Brand"))


for start_index in range(start, end, display):

    url = "https://openapi.naver.com/v1/search/shop?query=" + query \
          + "&display=" + str(display) \
          + "&start=" + str(start_index) \
          + "&sort=" + sort


    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if(rescode==200): # 200은 정상적으로 응답받았다는 코드
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']

        for item_index in range(0, len(items)):

            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            image = items[item_index]['image']

            low_price = items[item_index]['lprice']
            high_price = items[item_index]['hprice']
            
            mall_name = items[item_index]['mallName']
            product_id = items[item_index]['productId']
            product_type = items[item_index]['productType']

            maker = items[item_index]['maker']
            brand = items[item_index]['brand']

            

            shop_df.loc[idx] = [title, link, image, low_price, high_price,
                                mall_name, product_id, product_type, maker, brand]
            idx += 1
    else:
        print("Error Code:" + rescode)


shop_df
# Out:
# 검색 질의: 컴퓨터
#                                                Title  ...  Brand
# 0                             로스트아크 서든어택 롤 배틀그라운드컴퓨터  ...
# 1                                    배틀그라운드 오버워치조립PC  ...
# 2                              삼성전자 삼성 DM530ABE-L58A  ...     삼성
# 3                  아싸컴 프리미엄 게이밍 i5-9400F + 외장형 그래픽카드  ...    아싸컴
# 4    애플 2019 아이맥 27인치 5K 기본형MRQY2KH/A SSD 528GB 교체장착  ...    아이맥
# ..                                               ...  ...    ...
# 995                           기가바이트 GB-BPCE-3455 SSD  ...
# 996            마이컴 사무용PC 초고속부팅 빠른 인터넷 가성비 프리미엄 조립컴퓨터  ...
# 997                   프리플로우 GAMING EDITION 998RTX 슈퍼  ...  프리플로우
# 998                           인텔 NUC8i7HVK WIN10 M.2  ...     인텔
# 999                            삼성전자 삼성 DM500S2A-A53S  ...     삼성
#
# [1000 rows x 10 columns]
