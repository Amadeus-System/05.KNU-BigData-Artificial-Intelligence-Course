# %% [markdown]
# # BeautyfulSoup 네이버 영화 리뷰 스크래핑

# %% [markdown]
# ## 네이버 영화 리뷰 스크래핑
#
# * 네이버 영화: https://movie.naver.com/movie/point/af/list.nhn

# %%
from bs4 import BeautifulSoup
import urllib.request
from urllib.parse import quote
import pandas as pd


def get_movie_reviews(mcode, page_num = 10):

    movie_review_df = pd.DataFrame(columns = ('Title', 'Score', 'Review'))
    url = "https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=" + str(mcode) + "&target=after"

    idx = 0


    for _ in range(0, page_num):
        movie_page = urllib.request.urlopen(url).read()
        movie_page_soup = BeautifulSoup(movie_page, 'html.parser')

        review_list = movie_page_soup.find_all('td', {'class' : 'title'})
        for review in review_list:
            title = review.find("a", {'class':'movie color_b'}).get_text()
            score = review.find('em').get_text()
            review_text = review.find('a', {'class':'report'}).get('href').split(',')[2]
            movie_review_df.loc[idx] = [title, score, review_text]
            idx += 1
            print("#", end="")

        try:
            url = "https://movie.naver.com" + movie_page_soup.find('a', {'class':'pg_next'}).get('href')
            print(url)
        except:
            break

    return movie_review_df

# %%
movie_review_df = get_movie_reviews(189069, 1)
movie_review_df
# Out:
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=189069&target=after&page=2
#          Title Score                                             Review
# 0  다만 악에서 구하소서    10   '바로전에 살아있다를 봐서 그런지 영화의 개연성이나 짜임새는 좋았다. 황정민이 납...
# 1  다만 악에서 구하소서    10   '이 영화는 모든 감정이 눈에서 나오는거같음. 말보단 모든 말이 얼굴로 다해서 눈...
# 2  다만 악에서 구하소서    10                                   '아주아주아주아주조아요~^^'
# 3  다만 악에서 구하소서     5                                         '연기는 볼만해요'
# 4  다만 악에서 구하소서     7                          '보고싶었던 영화였음 ! 끝까지 보고나옴 !'
# 5  다만 악에서 구하소서     8   '요새 볼만한 영화 많이 없었는데 재밌습니다. 배우들 연기 너무 잘하고요. 스토리...
# 6  다만 악에서 구하소서    10   '박정민 출연료가 적지않을건데 왜 굳이 박정민을 썻을까 의아함. 본시리즈에 나왔던...
# 7  다만 악에서 구하소서     4   '코로나 때문에 중간 엎으려다 찍어놓은 액션 씬 아까워서 대충 마무리 짓고 내보낸...
# 8  다만 악에서 구하소서    10                                  '리얼 개 10 꿀잼 꼭 봐라'
# 9  다만 악에서 구하소서    10                                                 ''

# %%
movie_review_df = get_movie_reviews(18847, 10)
movie_review_df
# Out:
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=18847&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=18847&target=after&page=3
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=18847&target=after&page=4
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=18847&target=after&page=5
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=18847&target=after&page=6
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=18847&target=after&page=7
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=18847&target=after&page=8
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=18847&target=after&page=9
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=18847&target=after&page=10
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=18847&target=after&page=11
#    Title Score                                    Review
# 0   타이타닉    10                       '16년 살면서 많은 영화들을 보고
# 1   타이타닉    10                 '뭐 말 할 필요 있을까 그냥 보시면 압니다'
# 2   타이타닉    10        '감동적이고 정말 재밌게 봤네요.3시간이 지루하지 않았어요.'
# 3   타이타닉    10    '살면서 꼭 봐야할 영화에요. 안보신 분들은 꼭 봐야 합니다!!!!'
# 4   타이타닉    10                                        ''
# ..   ...   ...                                       ...
# 95  타이타닉    10                                        ''
# 96  타이타닉    10   '생애 최고의 영화입니다. 극장서3번을 봤어도 여전히 감동이었어요. '
# 97  타이타닉    10             '아름다운 사랑은 기억속에서 절대 잊혀지지 않는다.'
# 98  타이타닉    10                            '아주 재밌는 영화네요굿'
# 99  타이타닉    10               '영화관에서 하루만이라도 재개봉 해 줬으면...'
#
# [100 rows x 3 columns]

# %% [markdown]
# ## 현재상영작 영화 리뷰 스크래핑

# %%
url = "https://movie.naver.com/movie/point/af/list.nhn"

naver_movie = urllib.request.urlopen(url).read()
soup = BeautifulSoup(naver_movie, 'html.parser')
select = soup.find('select', {'id':'current_movie'})
movies = select.find_all('option')

movies_dict = {}
for movie in movies[1:]:
    movies_dict[movie.get('value')] = movie.get_text()


movie_review_df = pd.DataFrame(columns = ('Title', 'Score', 'Review'))

for mcode in movies_dict:
    df = get_movie_reviews(mcode, 1)
    movie_review_df = pd.concat([movie_review_df, df])

movie_review_df
# Out:
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=195180&target=after&page=2
# ###################https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=189069&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=134824&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=182809&target=after&page=2
# ###################https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=185269&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=174261&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=189747&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=189622&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=188909&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=194799&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=168051&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=194791&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=194294&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=185273&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=194486&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=194285&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=194284&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=186931&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=183429&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=194295&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=194765&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=194693&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=187294&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=194688&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=185917&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=192066&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=186235&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=36651&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=194661&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=194007&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=194368&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=191143&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=186348&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=79770&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=37742&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=173247&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=185151&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=194807&target=after&page=2
# #############https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=84917&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=189118&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=189537&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=185292&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=189633&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=169647&target=after&page=2
# ###############https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=187351&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=188162&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=10480&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=186347&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=180378&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=185380&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=178569&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=178520&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=192623&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=106360&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=179394&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=185285&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=85825&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=190447&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=185136&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=152691&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=14448&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=189438&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=190620&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=182042&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=10001&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=193839&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=191642&target=after&page=2
# #############https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=185150&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=134963&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=172181&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=189624&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=189028&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=189123&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=179414&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=17970&target=after&page=2
# ####################https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=174294&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=52515&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=180851&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=185282&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=190223&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=29059&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=153934&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=181710&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=146068&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=10086&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=182387&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=179392&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=174797&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=179398&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=179307&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=10323&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=176625&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=185149&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=185131&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=16411&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=179397&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=163788&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=27111&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=179506&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=168711&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=168743&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=174830&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=168744&target=after&page=2
# ###############https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=168050&target=after&page=2
# ################https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=27219&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=159311&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=156912&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=138601&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=162816&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=155716&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=40932&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=56220&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=150372&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=136872&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=155123&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=147945&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=136870&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=146504&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=134899&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=124238&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=121922&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=123298&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=101248&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=37544&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=103535&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=78726&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=32588&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=69952&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=41554&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=39894&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=10566&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=10489&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=10710&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=10592&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=10182&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=13575&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=20324&target=after&page=2
# ##########https://movie.naver.com/movie/point/af/list.nhn?st=mcode&sword=10621&target=after&page=2
# #######
#           Title Score                                             Review
# 0   주식회사 스페셜액터스    10   '전작인 카멈처럼 신선하진 않았지만 예측 가능한 스토리를 충분히 즐겁게 볼 수 있...
# 1   주식회사 스페셜액터스     9                                  '반전의 반전의 반전 ㄷㄷㄷㄷ'
# 2   주식회사 스페셜액터스     9                '마지막감동..간만에 본 영화인데 시간과 돈이 아깝지 않았네요'
# 3   주식회사 스페셜액터스    10                                       '너무 웃겼어욬ㅋㅋㅋ'
# 4   주식회사 스페셜액터스     8               '허구의 진실 속에서 외면을 넘어 내면을 이겨내는  그런게 연기고
# ..          ...   ...                                                ...
# 2      말 없는 사나이    10   '왜 재밌는지 모르게 재밌다. 특히나 자전거 데이트씬은 근래 보았던 어떤 최신멜로...
# 3      말 없는 사나이     7                                     '나는 희극이 별로에요.'
# 4      말 없는 사나이    10            '&amp;#34;말 없는 사나이&amp;#34;는 서부 영화 제목같고
# 5      말 없는 사나이     1                                    '내가본것중최악 시간아깝다'
# 6      말 없는 사나이    10   '&amp;#39;아일랜드 기질&amp;#39;이 뭔지를 확실히 보여주는 코미디....
#
# [1437 rows x 3 columns]
