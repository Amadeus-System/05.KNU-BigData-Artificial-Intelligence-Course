# %% [markdown]
# # 한국환경공단 대기오염정보

# %% [markdown]
# ## 한국환경공단_측정소정보
#
# * https://data.go.kr/tcs/dss/selectApiDataDetailView.do?publicDataPk=15000660

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
from xml.etree import ElementTree
import pandas as pd

skey = "BzdmQ%2F7904bk93mvskTbWy5JumYn6WH8FnsogRiwtZopZ8UezxFPG65B0GA6LaSxU%2B7Df0N2fRxPZsmu5TQ0Iw%3D%3D"

url = 'http://openapi.airkorea.or.kr/openapi/services/rest/MsrstnInfoInqireSvc/getNearbyMsrstnList'

params = '?' + 'ServiceKey=' + skey + '&' + \
urlencode({ quote_plus('tmX') : '244148.546388', 
           quote_plus('tmY') : '412423.75772', 
           quote_plus('ver') : '1.0' })
print(url + params)


request = Request(url + params)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
#print(response_body)


root = ElementTree.fromstring(response_body)

df = pd.DataFrame()
for item in root.iter('item'):
    item_dict = {}
    item_dict["stationName"] = item.find('stationName').text
    item_dict["addr"] = item.find('addr').text
    item_dict["tm"] = item.find('tm').text
    #print(item_dict)
    
    df = df.append(item_dict, ignore_index = True)


df
# Out:
# http://openapi.airkorea.or.kr/openapi/services/rest/MsrstnInfoInqireSvc/getNearbyMsrstnList?ServiceKey=BzdmQ%2F7904bk93mvskTbWy5JumYn6WH8FnsogRiwtZopZ8UezxFPG65B0GA6LaSxU%2B7Df0N2fRxPZsmu5TQ0Iw%3D%3D&tmX=244148.546388&tmY=412423.75772&ver=1.0
#                                    addr stationName   tm
# 0  제주 서귀포시 대정읍 동일하모로149번길 21-8대정청소년 수련관         대정읍  0.0
# 1    부산 동구 충장대로 314자성대부두(관공선부두) 내 (좌천동)        부산북항  0.0
# 2                    제주 제주시 한경면 고산리3762         고산리  0.0

# %% [markdown]
# ## 한국환경공단_대기오염정보
#
# * https://data.go.kr/tcs/dss/selectApiDataDetailView.do?publicDataPk=15000581

# %% [markdown]
# ### 측정소별 실시간 측정정보 조회

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
from xml.etree import ElementTree
import pandas as pd

skey = "Z4rahMlf7472Ig19BMvNc3yAvtsC%2BNdm5a8jTTyHDYLkU86W7oKypWd5cVK2EjpfQvJ43mL9gCBTLc6C7eGBGA%3D%3D"

url = 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty'
params = '?' + 'ServiceKey=' + skey + '&' + \
urlencode({ quote_plus('numOfRows') : '10', 
           quote_plus('pageNo') : '1', 
           quote_plus('stationName') : '종로구', 
           quote_plus('tmY') : 'DAILY', 
           quote_plus('ver') : '1.3' })
print(url + params)


request = Request(url + params)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
#print(response_body)


root = ElementTree.fromstring(response_body)

df = pd.DataFrame()
for item in root.iter('item'):
    item_dict = {}
    item_dict["stationName"] = item.find('stationName').text
    item_dict["addr"] = item.find('addr').text
    item_dict["tm"] = item.find('tm').text
    item_dict["tm"] = item.find('tm').text
    item_dict["tm"] = item.find('tm').text
    item_dict["tm"] = item.find('tm').text
    item_dict["tm"] = item.find('tm').text
    item_dict["tm"] = item.find('tm').text
    item_dict["tm"] = item.find('tm').text
    item_dict["tm"] = item.find('tm').text
    item_dict["tm"] = item.find('tm').text
    item_dict["tm"] = item.find('tm').text
    item_dict["tm"] = item.find('tm').text
    item_dict["tm"] = item.find('tm').text
    item_dict["tm"] = item.find('tm').text
    item_dict["tm"] = item.find('tm').text
    item_dict["tm"] = item.find('tm').text
    
    df = df.append(item_dict, ignore_index = True)


df
# Out:
# http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty?ServiceKey=Z4rahMlf7472Ig19BMvNc3yAvtsC%2BNdm5a8jTTyHDYLkU86W7oKypWd5cVK2EjpfQvJ43mL9gCBTLc6C7eGBGA%3D%3D&numOfRows=10&pageNo=1&stationName=%EC%A2%85%EB%A1%9C%EA%B5%AC&tmY=DAILY&ver=1.3
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 시도별 실시간 측정정보 조회

# %% [markdown]
# ### 시도별 실시간 평균정보 조회

# %% [markdown]
# ### 시군구별 실시간 평균정보 조회
